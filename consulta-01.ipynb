# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv('MICRODADOS.csv', sep=";", encoding='latin1', low_memory=False)

# %%
df.query('Municipio == "CARIACICA" & ComorbidadeTabagismo == "Sim" & DataObito >= "2020" & Evolucao == "Óbito pelo COVID-19"')
# Out:
#         DataNotificacao DataCadastro DataDiagnostico DataColeta_RT_PCR  \
# 90673        2022-12-29   2022-12-29      2022-12-27               NaN
# 659736       2022-07-13   2022-07-13      2022-07-12        2022-07-13
# 771724       2022-07-04   2022-07-04      2022-07-04        2022-07-04
# 773119       2022-07-04   2022-07-04      2022-07-04               NaN
# 933095       2022-06-22   2022-06-22      2022-06-19               NaN
# ...                 ...          ...             ...               ...
# 4699706      2020-05-08   2020-05-08      2020-05-03        2020-05-08
# 4700276      2020-05-07   2020-05-08      2020-05-04        2020-05-07
# 4705057      2020-05-04   2020-05-04      2020-04-25        2020-05-05
# 4705537      2020-05-03   2020-05-03      2020-05-01        2020-05-02
# 4715273      2020-04-20   2020-04-20      2020-04-13        2020-04-20
#
#         DataColetaTesteRapido DataColetaSorologia DataColetaSorologiaIGG  \
# ...
